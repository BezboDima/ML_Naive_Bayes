# %%
from DataControl import DataControl

iris = DataControl("data/iris.data", ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"])
iris.data_processed
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 0             4.8          3.1           1.6          0.2      Iris-setosa
# 1             5.1          3.5           1.4          0.2      Iris-setosa
# 2             6.0          3.0           4.8          1.8   Iris-virginica
# 3             5.8          2.7           4.1          1.0  Iris-versicolor
# 4             7.6          3.0           6.6          2.1   Iris-virginica
# ..            ...          ...           ...          ...              ...
# 145           6.6          2.9           4.6          1.3  Iris-versicolor
# 146           5.1          3.7           1.5          0.4      Iris-setosa
# 147           5.0          3.3           1.4          0.2      Iris-setosa
# 148           5.6          2.9           3.6          1.3  Iris-versicolor
# 149           6.2          2.2           4.5          1.5  Iris-versicolor
#
# [150 rows x 5 columns]

# %%
iris.continious_to_categorical(["sepal_length", "sepal_width", "petal_length", "petal_width"])

iris.hot_encoding_categorical(["class"])

iris.data_processed
# Out:
#     sepal_length sepal_width petal_length petal_width  class
# 0              1           3            2           1      0
# 1              2           5            1           1      0
# 2              3           2            4           4      2
# 3              3           1            3           2      1
# 4              5           2            5           5      2
# ..           ...         ...          ...         ...    ...
# 145            5           2            3           3      1
# 146            2           5            1           2      0
# 147            1           4            1           1      0
# 148            2           2            2           3      1
# 149            4           1            3           3      1
#
# [150 rows x 5 columns]

# %%
from Evaluation import Evaluation
evaluation_instance = Evaluation(iris, "class")

# %%
evaluation_instance.run_eval()
print(evaluation_instance.get_avg_precision())
print(evaluation_instance.get_avg_recall())
# Out:
# {2: 0.34074074074074073, 0: 0.3333333333333333, 1: 0.32592592592592595}
# {1:     sepal_length sepal_width petal_length petal_width
# 0              4           2            3           3
# 12             2           2            3           3
# 15             3           2            3           3
# 17             1           1            2           2
# 18             2           1            2           2
# 21             5           4            4           3
# 23             3           1            3           2
# 24             2           2            3           3
# 25             2           1            2           2
# 27             2           1            2           2
# 28             5           2            4           4
# 30             3           2            3           3
# 31             2           1            3           3
# 32             3           1            2           2
# 33             5           3            3           3
# ...

# %%
iris.noise("class")

evaluation_instance = Evaluation(iris, "class")
evaluation_instance.run_eval()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'p'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 iris.noise("class")
# ...
