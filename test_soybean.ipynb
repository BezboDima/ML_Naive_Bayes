# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
soybean_small = fetch_ucirepo(id=91) 
  
# data (as pandas dataframes) 
X = soybean_small.data.features 
y = soybean_small.data.targets 
   
  
# variable information 
columns = soybean_small.variables.name.to_list()

# %%
from DataControl import DataControl

soybean = DataControl("data/soybean-small.data", columns)
soybean.hot_encoding_categorical(["class"])

soybean.data_processed
# Out:
#     date  plant-stand  precip  temp  hail  crop-hist  area-damaged  severity  \
# 0      3            0       2     1     0          2             1         1
# 1      1            1       2     0     0          3             1         1
# 2      3            1       2     0     0          1             1         2
# 3      6            0       0     1     1          3             3         1
# 4      3            0       0     2     1          0             2         1
# 5      2            1       2     1     1          1             1         2
# 6      6            0       0     2     0          1             3         1
# 7      3            1       1     0     0          2             1         2
# 8      2            1       2     0     0          2             1         1
# 9      5            0       2     1     0          2             0         1
# 10     3            1       2     0     0          2             1         2
# ...

# %%
from Evaluation import Evaluation
evaluation_instance = Evaluation(soybean, "class")

# %%
evaluation_instance.run_eval()
print(evaluation_instance.get_avg_precision())
print(evaluation_instance.get_avg_recall())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 evaluation_instance.run_eval()
#       2 print(evaluation_instance.get_avg_precision())
#       3 print(evaluation_instance.get_avg_recall())
#
# NameError: name 'evaluation_instance' is not defined
